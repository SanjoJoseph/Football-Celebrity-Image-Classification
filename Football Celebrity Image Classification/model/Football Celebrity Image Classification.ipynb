# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./dataset/Cristiano Ronaldo/Cristiano Ronaldo (12).jpg')
img.shape
# Out:
# (405, 270, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (405, 270)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 63,  34, 136, 136]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (63, 34, 136, 136)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (136, 136, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./dataset/Cristiano Ronaldo/Cristiano Ronaldo (12).jpg')
plt.imshow(cropped_image)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./dataset/Cristiano Ronaldo/Cristiano Ronaldo (96).jpg')
cropped_image_no_2_eyes

# %%
img = cv2.imread('./dataset/Kylian Mbappe/Kylian Mbappe (21).jpg')
cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# array([[11, 12, 13, ..., 12, 12, 12],
#        [11, 12, 13, ..., 12, 12, 12],
#        [12, 12, 13, ..., 11, 11, 11],
#        ...,
#        [24, 22, 20, ...,  5,  5,  4],
#        [27, 24, 22, ...,  5,  5,  5],
#        [29, 26, 24, ...,  5,  5,  5]], dtype=uint8)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Cristiano Ronaldo',
#  './dataset/Kylian Mbappe',
#  './dataset/Lionel Messi',
#  './dataset/Mohammed Salah',
#  './dataset/Son Heung Min']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Cristiano Ronaldo
# Generating cropped images in folder:  ./dataset/cropped/Kylian Mbappe
# Generating cropped images in folder:  ./dataset/cropped/Lionel Messi
# Generating cropped images in folder:  ./dataset/cropped/Mohammed Salah
# Generating cropped images in folder:  ./dataset/cropped/Son Heung Min

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Cristiano Ronaldo': ['./dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo1.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo10.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo11.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo12.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo13.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo14.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo15.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo16.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo17.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo18.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo19.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo2.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo20.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo21.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo22.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo24.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo25.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo26.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo28.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo3.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo30.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo31.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo32.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo34.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo35.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo36.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo37.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo38.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo39.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo4.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo40.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo41.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo42.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo43.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo44.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo45.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo46.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo47.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo48.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo49.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo5.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo50.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo51.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo53.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo54.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo55.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo56.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo57.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo58.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo59.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo6.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo60.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo61.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo64.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo65.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo66.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo67.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo68.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo7.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo70.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo71.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo73.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo74.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo75.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo76.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo77.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo78.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo8.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo80.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo81.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo83.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo84.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo87.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo9.png'],
#  'Kylian Mbappe': ['./dataset/cropped/Kylian Mbappe\\Kylian Mbappe1.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe10.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe11.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe12.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe13.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe14.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe15.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe16.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe17.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe18.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe19.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe2.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe20.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe21.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe22.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe23.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe24.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe25.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe26.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe27.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe28.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe29.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe3.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe30.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe31.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe32.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe33.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe34.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe35.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe36.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe37.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe38.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe39.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe4.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe40.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe42.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe43.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe44.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe45.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe46.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe47.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe48.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe49.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe5.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe50.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe51.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe52.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe6.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe7.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe8.png',
#   './dataset/cropped/Kylian Mbappe\\Kylian Mbappe9.png'],
#  'Lionel Messi': ['./dataset/cropped/Lionel Messi\\Lionel Messi1.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi10.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi11.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi12.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi13.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi14.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi15.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi16.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi18.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi19.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi20.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi22.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi23.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi24.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi25.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi26.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi27.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi29.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi3.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi30.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi31.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi32.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi33.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi34.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi35.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi37.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi38.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi39.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi4.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi40.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi41.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi42.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi43.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi45.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi46.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi47.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi48.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi49.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi5.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi50.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi51.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi52.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi54.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi55.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi56.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi57.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi59.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi6.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi60.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi61.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi62.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi64.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi65.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi66.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi67.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi68.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi69.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi7.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi70.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi71.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi72.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi73.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi74.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi75.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi76.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi77.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi79.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi80.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi81.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi82.png',
#   './dataset/cropped/Lionel Messi\\Lionel Messi9.png'],
#  'Mohammed Salah': ['./dataset/cropped/Mohammed Salah\\Mohammed Salah1.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah10.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah11.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah13.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah14.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah15.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah16.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah17.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah18.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah19.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah2.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah20.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah21.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah22.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah23.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah24.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah25.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah26.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah27.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah28.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah29.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah3.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah30.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah31.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah34.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah4.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah5.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah6.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah7.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah8.png',
#   './dataset/cropped/Mohammed Salah\\Mohammed Salah9.png'],
#  'Son Heung Min': ['./dataset/cropped/Son Heung Min\\Son Heung Min1.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min10.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min11.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min12.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min14.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min15.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min17.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min18.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min19.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min2.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min20.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min22.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min23.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min24.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min25.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min26.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min27.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min28.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min29.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min3.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min30.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min31.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min4.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min5.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min6.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min7.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min8.png',
#   './dataset/cropped/Son Heung Min\\Son Heung Min9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Cristiano Ronaldo': 0,
#  'Kylian Mbappe': 1,
#  'Lionel Messi': 2,
#  'Mohammed Salah': 3,
#  'Son Heung Min': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[65],
#        [63],
#        [62],
#        ...,
#        [14],
#        [49],
#        [ 0]], dtype=uint8)

# %%
y[245]
# Out:
# 4

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (255, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.828125

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.811336
# 1        random_forest    0.560189
# 2  logistic_regression    0.759109
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9375

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.546875

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.875

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[17,  1,  1,  0,  0],
#        [ 0,  8,  0,  0,  0],
#        [ 0,  1, 21,  0,  0],
#        [ 0,  0,  0,  8,  0],
#        [ 0,  1,  0,  0,  6]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Cristiano Ronaldo': 0,
#  'Kylian Mbappe': 1,
#  'Lionel Messi': 2,
#  'Mohammed Salah': 3,
#  'Son Heung Min': 4}

# %%
import joblib
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
